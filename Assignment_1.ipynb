# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns

# Load the dataset into a pandas DataFrame
df = pd.read_csv('/content/House Price India.csv')

# Check for missing data
print(df.isnull().sum())

# Explore the features of the dataset using descriptive statistics
print(df.describe())

# Explore the features of the dataset using visualizations
sns.histplot(data=df, x="Price")
sns.histplot(data=df, x="living area")
sns.boxplot(x=df['number of bedrooms'], y=df['Price'])

# Perform univariate analysis on each feature
sns.histplot(data=df, x="Price")
sns.histplot(data=df, x="living area")
sns.countplot(data=df, x="number of bedrooms")

# Perform bivariate analysis to investigate the relationships between pairs of features
sns.scatterplot(data=df, x="living area", y="Price")
sns.boxplot(x=df['number of bedrooms'], y=df['Price'])

# Perform multivariate analysis to investigate the relationships between three or more features
sns.pairplot(df[['Price', 'living area', 'number of bedrooms', 'number of bathrooms']])
print(df.describe())

import pandas as pd

# Import the file and read it into a pandas DataFrame
data = pd.read_csv('/content/House Price India.csv')  # Replace 'your_file.csv' with the actual file path

# Check for missing values
missing_data = data.isnull().sum()

# Print the columns with missing values
print("Columns with missing values:")
print(missing_data[missing_data > 0])

# Print the total number of missing values
print("\nTotal number of missing values:", missing_data.sum())
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...
